# %% [markdown]
# # config

# %%
from getpass import getpass
import requests, json

token = getpass("Enter GitHub token (hidden): ")

r = requests.get("https://api.github.com/user", headers={"Authorization": f"token {token}"})
print(r.status_code)
print(r.json().get("login"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-600939327.py in <cell line: 0>()
#       2 import requests, json
#       3
# ----> 4 token = getpass("Enter GitHub token (hidden): ")
#       5
#       6 r = requests.get("https://api.github.com/user", headers={"Authorization": f"token {token}"})
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#    1157                 stacklevel=2,
#    1158             )
# -> 1159         return self._input_request(
#    1160             prompt,
#    1161             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
username = "Vu-Quoc-Tuan"
repo_name = "BTL-NLP-2526I_INT3406_3"

# Sử dụng biến token để xác thực trực tiếp trong URL
# !git clone https://{token}@github.com/{username}/{repo_name}

# %%
# 1) vào thư mục repo (thay path nếu khác)
# %cd /content/BTL-NLP-2526I_INT3406_3

# 2) kiểm tra hiện tại đang ở đâu và liệt kê file
# !pwd
# !ls -la
# !ls -la vlsp-mt
# !test -f vlsp-mt/requirements.txt && echo "requirements found" || echo "requirements NOT found"

# 3) show python interpreter đang dùng
import sys
print("Python executable:", sys.executable)

# 4) dùng chính interpreter đó để cài (an toàn hơn dùng !pip trực tiếp)
# !{sys.executable} -m pip install -r vlsp-mt/requirements.txt

# %% [markdown]
# # Run script

# %% [markdown]
# ## Preprocessing

# %%
# %cd vlsp-mt

# %%
# !python scripts/dedup_minhash.py \
    --src data/clean/train.en \
    --tgt data/clean/train.vi \
    --out_dir data/dedup \
    --threshold 0.8 \
    --dedup_by both \
    --rep_strategy longest \
    --smart_threshold

# %% [markdown]
# ## Train

# %%
# !pip install evaluate

# %%
# !python scripts/train_qwen_lora.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --direction en2vi \
    --src data/clean/train.en \
    --tgt data/clean/train.vi \
    --val_src data/clean/dev.en \
    --val_tgt data/clean/dev.vi \
    --run_id en2vi_v1 \
    --epochs 2 \
    --batch_size 8 \
    --grad_accum 4 \
    --lr 1.5e-4 \
    --lora_r 32 \
    --lora_alpha 64 \
    --neftune_alpha 3.0 \
    --bleu_sample_size 200 \
    --eval_steps 1000 \
    --early_stopping_patience 2 \
    --no_grad_checkpoint  \
    --max_len 256

# %%
# 1. Tạo thư mục đích trước
# !mkdir -p data/rl_subset

# 2. Chạy lệnh cắt file
# !head -n 20000 data/dedup/train.en > data/rl_subset/en.txt
# !head -n 20000 data/dedup/train.vi > data/rl_subset/vi.txt

# !ls -lh data/rl_subset/

# %%
# !python scripts/rl_train_grpo.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --sft_adapter runs/en2vi_v1/lora_en2vi_sft \
    --init_adapter runs/en2vi_v1/lora_en2vi_sft \
    --rl_src data/rl_subset/en.txt \
    --rl_tgt data/rl_subset/vi.txt \
    --run_id en2vi_v1_rl \
    --direction en2vi \
    --epochs 1 \
    --batch_size 4 \
    --grad_accum_steps 8 \
    --lr 3e-6 \
    --kl_coef 0.02 \
    --temperature 0.8 \
    --max_new_tokens 64

# %% [markdown]
# # augemnet

# %%
# !python scripts/back_translate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/vi2en_v1/lora_vi2en_sft \
    --input data/rl_subset/vi.txt \
    --output data/augment/bt.en \
    --direction vi2en \
    --batch_size 16 \
    --temperature 0.7

# %%
# !cat data/clean/test.en data/augment/bt.en > data/augment/train_aug_en2vi.en
# !cat data/clean/test.vi data/rl_subset/vi.txt > data/augment/train_aug_en2vi.vi

# %%
# !python scripts/train_qwen_lora.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --direction en2vi \
    --src data/augment/train_aug.en \
    --tgt data/augment/train_aug.vi \
    --val_src data/clean/dev.en \
    --val_tgt data/clean/dev.vi \
    --run_id en2vi_v2_aug \
    --epochs 2 \
    --batch_size 8 \
    --grad_accum 4 \
    --lr 1.5e-4 \
    --lora_r 32 \
    --lora_alpha 64 \
    --neftune_alpha 3.0 \
    --bleu_sample_size 200 \
    --eval_steps 500 \
    --early_stopping_patience 3 \
    --no_grad_checkpoint  \
    --max_len 256

# %% [markdown]
# ## Eval

# %%
data/raw/test_unseen_v3.vi.txt

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v1/lora_en2vi_sft \
    --direction en2vi \
    --input data/raw/test_unseen_v3.en.txt \
    --output outputs/test_unseen_v3.hyp.vi \
    --batch_size 24 \
    --num_beams 4 \
    --repetition_penalty 1.1
# Out:
# 2025-12-22 20:57:03.509803: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-22 20:57:03.529379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766437023.553848  324096 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766437023.560770  324096 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766437023.578067  324096 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766437023.578105  324096 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766437023.578108  324096 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766437023.578111  324096 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-22 20:57:03.583318: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Loading adapter: runs/en2vi_v1/lora_en2vi_sft
# Loaded tokenizer from adapter (may include medical vocab)
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.02it/s]
# Resizing embeddings: 151936 -> 151665
# Model loaded on cuda:0, dtype=torch.bfloat16
# Loaded 1152 sentences from data/raw/test_unseen_v3.en.txt
# Generating:   0% 0/48 [00:00<?, ?it/s]/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py:257: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast(dtype=torch.bfloat16):
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating: 100% 48/48 [10:38<00:00, 13.31s/it]
#
# Saved 1152 translations to outputs/test_unseen_v3.hyp.vi

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/test_unseen_v3.hyp.vi \
    --ref data/raw/test_unseen_v3.vi.txt \
    --src data/raw/test_unseen_v3.en.txt \
    --show_worst 10
# Out:
# Loading hypothesis: outputs/test_unseen_v3.hyp.vi
# Loading reference: data/raw/test_unseen_v3.vi.txt
# Loading source: data/raw/test_unseen_v3.en.txt
#
# Evaluating 1152 sentence pairs...
# Downloading NLTK resource: wordnet
# Downloading NLTK resource: omw-1.4
#
# ==================================================
# EVALUATION RESULTS
# ==================================================
#   BLEU:    51.11
#   chrF++:  64.96
#   chrF:    65.13
#   TER:     42.43 (lower is better)
#   METEOR:  73.89
# ==================================================
#
# 10 WORST TRANSLATIONS (by BLEU):
# --------------------------------------------------
#
# [1] Line 504 | BLEU: 3.9 | chrF: 25.7
#   SRC: Initial experiences of Halo-gravity traction in treatment of extremely severe adult idiopathic scoliosis
#   HYP: Kinh nghiệm bước đầu điều trị vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn v
#   REF: Kinh nghiệm bước đầu ứng dụng kéo giãn bằng khung Halo điều trị bệnh nhân vẹo cột sống tự phát biến dạng rất lớn ở người trưởng thành
#
# [2] Line 840 | BLEU: 4.0 | chrF: 25.3
#   SRC: CRRT with CVVH mode improved renal function but no evidence of improvement the hospital mortality.
#   HYP: LMLT với chế độ CVVH cải thiện chức năng thận nhưng không cải thiện được tỉ lệ tử vong tại bệnh viện.
#   REF: Lọc máu liên tục được thực hiện với kỹ thuật CVVH giúp hồi phục chức năng thận ở bệnh nhân hậu sản, suy đa tạng có tổn thương thận cấp nhưng chưa có bằng chứng cải thiện tỷ lệ sống còn.
#
# [3] Line 915 | BLEU: 4.7 | chrF: 24.0
#   SRC: Mortality is 3 (13.6%), due to over missing of the tracheal tissue. One happened 5 days postoperatively, one after 3 weeks, and one after 4 months.
#   HYP: Tỉ lệ tử vong là 13,6% (3/2 1 trường hợp), tử vong sau mổ 5 ngày 1 trường hợp, tử vong sau mổ 3 tuần 1 trường hợp, tử vong sau mổ 4 tháng 1 trường hợp.
#   REF: Các khối u đều chiếm dưới 1/3 chiều dài khí quản.Có 3 trường hợp tử vong (13,6%), do mất đoạn khí quản lớn; một sau 5 ngày, một sau 3 tuần và một sau 4 tháng.
#
# [4] Line 694 | BLEU: 4.8 | chrF: 36.1
#   SRC: The genotypes observed were in agreement with those expected under Hardy-Weinberg equilibrium.
#   HYP: Các kiểu gen quan sát được phù hợp với kiểu gen dự đoán theo định luật Hardy-Weinberg.
#   REF: Sự phân bố kiểu gen ở quần thể nghiên cứu tuân theo quy luật cân bằng Hardy - Weinberg.
#
# [5] Line 556 | BLEU: 5.5 | chrF: 34.5
#   SRC: In this trial, adding simethicone to bowel preparation improved the effectiveness of bowel preparation.
#   HYP: Trong thử nghiệm này, việc bổ sung simethicone vào quá trình chuẩn bị ruột đã cải thiện hiệu quả của việc chuẩn bị ruột.
#   REF: Trong nghiên cứu này, kết hợp simethicone trong chuẩn bị NSĐT tăng hiệu quả làm sạch bọt ở đại tràng.
#
# [6] Line 1068 | BLEU: 6.0 | chrF: 30.0
#   SRC: 84.3% patients were only used alone IM / SC / IV Adrenaline.
#   HYP: 84,3% bệnh nhân chỉ được sử dụng đơn thuần Adrenaline tiêm bắp / tiêm dưới da / truyền tĩnh mạch.
#   REF: 84,3% chỉ dùng Adrenaline TB / TDD / TM đơn thuần, 15,7% có TTM Adrenaline.
#
# [7] Line 360 | BLEU: 6.1 | chrF: 38.9
#   SRC: More than one-third (33.3%) of participants with COVID-19 had anxiety / melancholy.
#   HYP: Hơn 1/3 (33,3%) người tham gia mắc COVID-19 có biểu hiện lo âu / trầm cảm.
#   REF: Có 33,3% người bệnh COVID-19 tham gia có lo lắng / u sầu.
#
# [8] Line 665 | BLEU: 6.2 | chrF: 37.9
#   SRC: Good recovery with no disability accounted for 87.21% of all patients during the 3 - month follow up.
#   HYP: Kết quả phục hồi tốt không có tàn tật chiếm 87,21% trong tổng số bệnh nhân trong thời gian theo dõi 3 tháng.
#   REF: 87,21% bệnh nhân không có di chứng sau 3 tháng xuất viện.
#
# [9] Line 683 | BLEU: 6.6 | chrF: 29.9
#   SRC: The study was conducted from 01/01/2015 to 30/09/2019 of 98 victims who died of brain damage.
#   HYP: Nghiên cứu được tiến hành từ 01/01/2015 đến 30/09/2019 của 98 nạn nhân tử vong do tổn thương não.
#   REF: Nghiên cứu được thực hiện từ ngày 01 tháng 01 năm 2015 đến ngày 30 tháng 9 năm 2019 chúng tôi thu thập được 98 trường hợp nạn nhân là những người bị chết có tổn thương dập não.
#
# [10] Line 1089 | BLEU: 6.6 | chrF: 32.2
#   SRC: This analgesic effect of both doses was observed until 40th minute.
#   HYP: Tác dụng giảm đau của cả hai liều đều được quan sát thấy cho đến thời điểm 40 phút.
#   REF: Tác dụng này của cả 2 liều kéo dài đến phút thứ 40.

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v1/lora_en2vi_sft \
    --direction en2vi \
    --input data/clean/test.en \
    --output outputs/test_en2vi.hyp.vi \
    --batch_size 24 \
    --num_beams 4 \
    --repetition_penalty 1.1
# Out:
# 2025-12-22 19:41:58.136004: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-22 19:41:58.154433: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766432518.176773  304989 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766432518.183392  304989 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766432518.200299  304989 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766432518.200340  304989 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766432518.200343  304989 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766432518.200346  304989 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-22 19:41:58.205412: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Loading adapter: runs/en2vi_v1/lora_en2vi_sft
# Loaded tokenizer from adapter (may include medical vocab)
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.02it/s]
# Resizing embeddings: 151936 -> 151665
# Model loaded on cuda:0, dtype=torch.bfloat16
# Loaded 1000 sentences from data/clean/test.en
# Generating:   0% 0/42 [00:00<?, ?it/s]/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py:257: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast(dtype=torch.bfloat16):
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating: 100% 42/42 [09:13<00:00, 13.17s/it]
#
# Saved 1000 translations to outputs/test_en2vi.hyp.vi

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/test_en2vi.hyp.vi \
    --ref data/clean/test.vi \
    --src data/clean/test.en \
    --show_worst 10
# Out:
# Loading hypothesis: outputs/test_en2vi.hyp.vi
# Loading reference: data/clean/test.vi
# Loading source: data/clean/test.en
#
# Evaluating 1000 sentence pairs...
# Downloading NLTK resource: wordnet
# Downloading NLTK resource: omw-1.4
#
# ==================================================
# EVALUATION RESULTS
# ==================================================
#   BLEU:    52.53
#   chrF++:  66.28
#   chrF:    66.36
#   TER:     39.75 (lower is better)
#   METEOR:  75.40
# ==================================================
#
# 10 WORST TRANSLATIONS (by BLEU):
# --------------------------------------------------
#
# [1] Line 860 | BLEU: 1.7 | chrF: 1.4
#   SRC: RESULT OF TREATMENT OF SEVERE PNEUMONIA IN CHILDREN FROM 1 MONTH TO FIVE YEARS OLD IN QUANG NINH PROVINC
#   HYP: ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ VIÊM PHỔI NẶNG Ở TRẺ EM TỪ 1 THÁNG ĐẾN 5 TUỔI TẠI TỈNH QUẢNG NINH
#   REF: Kết quả điều trị viêm phổi nặng ở trẻ từ 1tháng đến 5 tuổi tại Quảng Ninh
#
# [2] Line 315 | BLEU: 2.8 | chrF: 5.2
#   SRC: EVALUATION OF PRELIMINARY RESULTS OF ENDOSCOPIC LITHOTRIPSY THROUGH T-TUBE TRACT AT CAN THO CENTRAL GENERAL HOSPITAL FROM 2020 TO 2021
#   HYP: Đánh giá kết quả bước đầu điều trị sỏi đường mật bằng nội soi tán sỏi qua đường hầm Kehr tại Bệnh viện Đa khoa Trung ương Cần Thơ năm 2020-2021
#   REF: NGHIÊN CỨU ĐẶC ĐIỂM LÂM SÀNG, CẬN LÂM SÀNG VÀ ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ SÓT SỎI ĐƯỜNG MẬT BẰNG PHƯƠNG PHÁP TÁN SỎI ĐIỆN THUỶ LỰC QUA ĐƯỜNG HẦM KEHR TẠI BỆNH VIỆN ĐA KHOA TRUNG ƯƠNG CẦN THƠ NĂM 2020-2021
#
# [3] Line 596 | BLEU: 3.1 | chrF: 17.8
#   SRC: Minimally invasive aortic valve surgery
#   HYP: Phẫu thuật van động mạch chủ ít xâm lấn
#   REF: Vai trò phẫu thuật glenn trong điều trị bệnh tim bẩm sinh tím
#
# [4] Line 402 | BLEU: 3.4 | chrF: 13.8
#   SRC: He hasn't had anyfurther seizure episodes.
#   HYP: Bệnh nhân không có cơn động kinh nào tiếp theo.
#   REF: Trẻ không xuất hiện thêm co giật, huyết áp được kiểm soát.
#
# [5] Line 310 | BLEU: 3.9 | chrF: 34.8
#   SRC: - The minor craniocerebral traumas were not concerned and diagnosed soon.
#   HYP: - Chấn thương sọ não nhẹ không được quan tâm và chẩn đoán sớm.
#   REF: Chúng ta không qua tâm đến các chấn thương đầu nhẹ.
#
# [6] Line 868 | BLEU: 4.0 | chrF: 26.7
#   SRC: Forms for and information about reporting ADRs are available in the Physicians' Desk Reference and the FDA News Daily Drug Bulletin, as well as at the FDA Adverse Event Reporting System (FAERS; MedWatch: The FDA Safety Information and Adverse Event Reporting Program).
#   HYP: Các hình thức và thông tin về báo cáo ADR có sẵn trong Physicians 'Desk Reference và Tờ thông tin hàng ngày của FDA, cũng như tại FDA Adverse Event Reporting
#   REF: Các biểu mẫu và thông tin dùng để báo cáo các phản ứng bất lợi của thuốc có tại Physicians ’ Desk Reference (Tài liệu tham khảo tại bàn của bác sĩ) và FDA News Daily Drug Bulletin (Bản tin dược phẩm hàng ngày của FDA News), cũng như tại FDA Adverse Event Reporting System (Hệ thống báo cáo tác dụng phụ của FDA) (FAERS; MedWatch: The FDA Safety Information and Adverse Event Reporting Program (Chương trình báo cáo biến cố bất lợi và thông tin an toàn của FDA)).
#
# [7] Line 662 | BLEU: 4.8 | chrF: 25.5
#   SRC: CONCLUSION: Our experience of choosing the iliac fossa for kidney transplantation has showed that choosing RIF for all cases with RKD or LKD reveal no complication.
#   HYP: KẾT LUẬN: Kinh nghiệm của chúng tôi về việc lựa chọn hốc chậu để ghép thận cho thấy việc lựa chọn RIF cho tất cả các trường hợp có RKD hoặc LKD không có biến chứng.
#   REF: Bàn luận và kết luận: Kinh nghiệm về việc chọn lựa đường mổ chủ yếu là bên P trong ghép thận của loạt nghiên cứu: cho thấy có thể tiến hành chọn ghép bên HCP cho mọi quả thận lấy bằng phương pháp mổ mở hay mổ nội soi.
#
# [8] Line 101 | BLEU: 5.5 | chrF: 34.7
#   SRC: At the beginning of each period, a thorough professional prophylaxis was performed to remove all the dental plaque, stain, debris, calculus.
#   HYP: Trước mỗi đợt điều trị, bệnh nhân được thực hiện nạo vôi răng, làm sạch mảng bám, vôi răng, mảnh vụn.
#   REF: Vôi răng, mảng bám và vết dính được làm sạch hoàn toàn vào đầu mỗi giai đoạn.
#
# [9] Line 545 | BLEU: 5.6 | chrF: 41.1
#   SRC: Staff at tertiary education needs education and training for general physicians (23.9%), preventive medicine physicians (16.5%) and other universities (22.3%).
#   HYP: Cán bộ trường cao đẳng cần đào tạo, tập huấn cho bác sỹ đa khoa (23,9%), bác sỹ y học dự phòng (16,5%) và các trường khác (22,3%).
#   REF: Cán bộ trung cấp có nhu cầu đào tạo bác sĩ đa khoa 23,9%, bác sĩ y tế dự phòng 16,5%, đại học khác 22,3%.
#
# [10] Line 119 | BLEU: 5.9 | chrF: 24.2
#   SRC: Triple-negative breast carcinoma in women from vietnam and the united states: characterization of differential marker expression by tissue microarray
#   HYP: Ung thư vú bộ ba âm tính ở người việt nam và người mỹ: đặc điểm biểu hiện dấu ấn khác biệt bằng kỹ thuật mảng vi mô
#   REF: Nhận xét một số đặc điểm mô bệnh học và dấu ấn sinh họccarcinôm tuyến vú ở phụ nữ việt nam và hoa kỳ có er, prvà her-2/neu âm tính qua sử dụng kỹ thuật sắp xếp dãy mô

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v1_rl/final_model/policy \
    --direction en2vi \
    --input data/clean/test.en \
    --output outputs/test_en2vi_rl.hyp.vi \
    --batch_size 16 \
    --num_beams 4 \
    --repetition_penalty 1.1
# Out:
# 2025-12-22 19:56:49.954842: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-22 19:56:49.973749: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766433409.996848  308879 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766433410.003524  308879 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766433410.020875  308879 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766433410.020924  308879 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766433410.020928  308879 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766433410.020931  308879 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-22 19:56:50.026074: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Loading adapter: runs/en2vi_v1_rl/final_model/policy
# Loaded tokenizer from base model
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.01it/s]
# Resizing embeddings: 151936 -> 151665
# Model loaded on cuda:0, dtype=torch.bfloat16
# Loaded 1000 sentences from data/clean/test.en
# Generating:   0% 0/63 [00:00<?, ?it/s]/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py:257: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast(dtype=torch.bfloat16):
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating: 100% 63/63 [12:14<00:00, 11.66s/it]
#
# Saved 1000 translations to outputs/test_en2vi_rl.hyp.vi

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/test_en2vi_rl.hyp.vi \
    --ref data/clean/test.vi \
    --src data/clean/test.en \
    --show_worst 10
# Out:
# Loading hypothesis: outputs/test_en2vi_rl.hyp.vi
# Loading reference: data/clean/test.vi
# Loading source: data/clean/test.en
#
# Evaluating 1000 sentence pairs...
# Downloading NLTK resource: wordnet
# Downloading NLTK resource: omw-1.4
#
# ==================================================
# EVALUATION RESULTS
# ==================================================
#   BLEU:    52.00
#   chrF++:  65.88
#   chrF:    65.99
#   TER:     40.13 (lower is better)
#   METEOR:  74.93
# ==================================================
#
# 10 WORST TRANSLATIONS (by BLEU):
# --------------------------------------------------
#
# [1] Line 25 | BLEU: 0.6 | chrF: 10.4
#   SRC: U S. clinical trials investigating the effectiveness and safety of the procedure currently are being conducted. NHỮNG KỸ THUẬT GHÉP BÊN TRONG VÀ BÊN NGOÀI GIÁC MẠC Corneal inlays and onlays are inserts placed just beneath your eye's clear surface (cornea).
#   HYP: NHỮNG KỸ THUẬT GHÉP BÊN TRONG VÀ BÊN NGOÀI GIÁC MẠC Corneal inlays and onlays are inserts placed just beneath your eye 's clear surface (cornea).
#   REF: Các thủ nghiệm lâm sàng của Hoa Kỳ đang điều tra hiệu quả và sự an toàn của tiên trình hiện giờ đang được tiến hành theo hướng dẫn (conduct) Corneal Inlays & Onlays Inlays giác mạc và onlays giác mạc là sự chèn thêm đặt ngay bên dưới bề mặt trong veo của mắt (giác mạc) của bạn.
#
# [2] Line 860 | BLEU: 1.7 | chrF: 1.4
#   SRC: RESULT OF TREATMENT OF SEVERE PNEUMONIA IN CHILDREN FROM 1 MONTH TO FIVE YEARS OLD IN QUANG NINH PROVINC
#   HYP: ĐÁNH GIÁ KẾT QUẢ ĐIỀU TRỊ VIÊM PHỔI NẶNG Ở TRẺ EM TỪ 1 THÁNG ĐẾN 5 TUỔI TẠI TỈNH QUẢNG NINH
#   REF: Kết quả điều trị viêm phổi nặng ở trẻ từ 1tháng đến 5 tuổi tại Quảng Ninh
#
# [3] Line 949 | BLEU: 2.6 | chrF: 17.7
#   SRC: Fusidic acid 2% cream is not available in the United States.
#   HYP: Axit fusidic 2% không có sẵn ở Hoa Kỳ.
#   REF: Kem axit fusidic 2% bôi 3 đén 4 lần một ngày cho đến khi hết tổn thương là một biện pháp có hiệu quả nhưng thuốc này không có ở Mỹ.
#
# [4] Line 596 | BLEU: 3.1 | chrF: 17.8
#   SRC: Minimally invasive aortic valve surgery
#   HYP: Phẫu thuật van động mạch chủ ít xâm lấn
#   REF: Vai trò phẫu thuật glenn trong điều trị bệnh tim bẩm sinh tím
#
# [5] Line 402 | BLEU: 3.4 | chrF: 13.8
#   SRC: He hasn't had anyfurther seizure episodes.
#   HYP: Bệnh nhân không có cơn động kinh nào tiếp theo.
#   REF: Trẻ không xuất hiện thêm co giật, huyết áp được kiểm soát.
#
# [6] Line 310 | BLEU: 3.4 | chrF: 34.4
#   SRC: - The minor craniocerebral traumas were not concerned and diagnosed soon.
#   HYP: - Chấn thương sọ não mức độ nhẹ không được quan tâm và chẩn đoán sớm.
#   REF: Chúng ta không qua tâm đến các chấn thương đầu nhẹ.
#
# [7] Line 868 | BLEU: 3.6 | chrF: 25.4
#   SRC: Forms for and information about reporting ADRs are available in the Physicians' Desk Reference and the FDA News Daily Drug Bulletin, as well as at the FDA Adverse Event Reporting System (FAERS; MedWatch: The FDA Safety Information and Adverse Event Reporting Program).
#   HYP: Các hình thức và thông tin về báo cáo ADR có sẵn trong Physicians 'Desk Reference và Tờ tin hàng ngày của FDA, cũng như tại FDA Adverse Event Reporting
#   REF: Các biểu mẫu và thông tin dùng để báo cáo các phản ứng bất lợi của thuốc có tại Physicians ’ Desk Reference (Tài liệu tham khảo tại bàn của bác sĩ) và FDA News Daily Drug Bulletin (Bản tin dược phẩm hàng ngày của FDA News), cũng như tại FDA Adverse Event Reporting System (Hệ thống báo cáo tác dụng phụ của FDA) (FAERS; MedWatch: The FDA Safety Information and Adverse Event Reporting Program (Chương trình báo cáo biến cố bất lợi và thông tin an toàn của FDA)).
#
# [8] Line 101 | BLEU: 5.3 | chrF: 31.7
#   SRC: At the beginning of each period, a thorough professional prophylaxis was performed to remove all the dental plaque, stain, debris, calculus.
#   HYP: Trước mỗi đợt điều trị, các đối tượng được thực hiện nạo vôi răng, làm sạch mảng bám, mảnh vụn, vôi răng.
#   REF: Vôi răng, mảng bám và vết dính được làm sạch hoàn toàn vào đầu mỗi giai đoạn.
#
# [9] Line 505 | BLEU: 5.8 | chrF: 42.3
#   SRC: Objective: To investigate the impact of PCOS phenotypes on IVM outcomes.
#   HYP: Mục tiêu: Khảo sát ảnh hưởng của các kiểu hình hội chứng buồng trứng đa nang (HCBTĐN) đến kết quả IVM.
#   REF: Khảo sát tác động của kiểu hình HCBTĐN lên kết cục IVM.
#
# [10] Line 119 | BLEU: 5.9 | chrF: 24.2
#   SRC: Triple-negative breast carcinoma in women from vietnam and the united states: characterization of differential marker expression by tissue microarray
#   HYP: Ung thư vú bộ ba âm tính ở người việt nam và người mỹ: đặc điểm biểu hiện dấu ấn khác biệt bằng kỹ thuật mảng vi mô
#   REF: Nhận xét một số đặc điểm mô bệnh học và dấu ấn sinh họccarcinôm tuyến vú ở phụ nữ việt nam và hoa kỳ có er, prvà her-2/neu âm tính qua sử dụng kỹ thuật sắp xếp dãy mô

# %% [markdown]
# # Public test

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v1/lora_en2vi_sft \
    --direction en2vi \
    --input data/raw/public_test.en.txt \
    --output outputs/public_test_en2vi_sft.hyp.vi \
    --batch_size 20 \
    --num_beams 5 \
    --repetition_penalty 1.1
# Out:
# 2025-12-22 20:10:52.566897: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-22 20:10:52.586131: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766434252.609354  312460 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766434252.616040  312460 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766434252.633280  312460 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766434252.633324  312460 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766434252.633327  312460 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766434252.633330  312460 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-22 20:10:52.638556: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Loading adapter: runs/en2vi_v1/lora_en2vi_sft
# Loaded tokenizer from adapter (may include medical vocab)
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.02it/s]
# Resizing embeddings: 151936 -> 151665
# Model loaded on cuda:0, dtype=torch.bfloat16
# Loaded 3000 sentences from data/raw/public_test.en.txt
# Generating:   0% 0/150 [00:00<?, ?it/s]/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py:257: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast(dtype=torch.bfloat16):
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Generating: 100% 150/150 [32:34<00:00, 13.03s/it]
#
# Saved 3000 translations to outputs/public_test_en2vi_sft.hyp.vi

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/test_en2vi_rl.hyp.vi \
    --ref data/clean/test.vi \
    --src data/clean/test.en \
    --show_worst 10
# Out:
# Loading hypothesis: outputs/public_test_en2vi_sft.hyp.vi
# Loading reference: data/raw/public_test.vi.txt
# Loading source: data/raw/public_test.en.txt
#
# Evaluating 3000 sentence pairs...
# Downloading NLTK resource: wordnet
# Downloading NLTK resource: omw-1.4
#
# ==================================================
# EVALUATION RESULTS
# ==================================================
#   BLEU:    54.19
#   chrF++:  67.29
#   chrF:    67.40
#   TER:     39.22 (lower is better)
#   METEOR:  75.85
# ==================================================
#
# 10 WORST TRANSLATIONS (by BLEU):
# --------------------------------------------------
#
# [1] Line 2039 | BLEU: 3.1 | chrF: 27.7
#   SRC: In vascular imaging, this technique provides image quality that equals or surpasses that of conventional angiography.
#   HYP: Trong chẩn đoán hình ảnh mạch máu, kỹ thuật này cung cấp chất lượng hình ảnh tương đương hoặc vượt trội so với chụp mạch thông thường.
#   REF: Trong kỹ thuật chụp mạch máu lớn của lồng ngực (động mạch chủ, động mạch phổi...), chụp cắt lớp điện toán đa lát cắt này cho được các hình ảnh bằng hoặc rõ hơn chụp mạch máu quy ước.
#
# [2] Line 1898 | BLEU: 3.4 | chrF: 22.8
#   SRC: This study aims to improve the understanding of pathogenesis of psoriasis, resulting in better monitoring and treatment. Objective: To analyze the serum TNF-alpha levels in psoriatic patients to evaluate the concentrations, correlation with some clinical features.
#   HYP: Mục tiêu: Phân tích nồng độ TNF-alpha huyết thanh ở bệnh nhân vảy nến nhằm đánh giá nồng độ, mối tương quan với một số đặc điểm lâm sàng.
#   REF: Nghiên cứu này góp phần tìm hiểu rõ hơn về sinh bệnh học của bệnh vảy nến tại Việt Nam, từ đó làm cơ sở cho việc theo dõi và điều trị bệnh hiệu quả hơn Mục tiêu: Định lượng nồng độ TNF - huyết thanh ở những bệnh nhân vảy nến và so sánh nồng độ TNF - huyết thanh với độ nặng lâm sàng, thời gian mắc bệnh và tính chất khởi phát sớm của bệnh vảy nến.
#
# [3] Line 895 | BLEU: 3.9 | chrF: 25.7
#   SRC: Initial experiences of Halo-gravity traction in treatment of extremely severe adult idiopathic scoliosis
#   HYP: Kinh nghiệm bước đầu điều trị vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn vẹo cột sống không rõ căn nguyên người lớn v
#   REF: Kinh nghiệm bước đầu ứng dụng kéo giãn bằng khung Halo điều trị bệnh nhân vẹo cột sống tự phát biến dạng rất lớn ở người trưởng thành
#
# [4] Line 1554 | BLEU: 4.0 | chrF: 25.3
#   SRC: CRRT with CVVH mode improved renal function but no evidence of improvement the hospital mortality.
#   HYP: LMLT với chế độ CVVH cải thiện chức năng thận nhưng không cải thiện được tỉ lệ tử vong tại bệnh viện.
#   REF: Lọc máu liên tục được thực hiện với kỹ thuật CVVH giúp hồi phục chức năng thận ở bệnh nhân hậu sản, suy đa tạng có tổn thương thận cấp nhưng chưa có bằng chứng cải thiện tỷ lệ sống còn.
#
# [5] Line 1671 | BLEU: 4.5 | chrF: 24.0
#   SRC: Mortality is 3 (13.6%), due to over missing of the tracheal tissue. One happened 5 days postoperatively, one after 3 weeks, and one after 4 months.
#   HYP: Tỉ lệ tử vong là 13,6% (3/2 1 trường hợp), tử vong sau mổ 5 ngày là 1 trường hợp, tử vong sau mổ 3 tuần là 1 trường hợp, tử vong sau mổ 4 tháng là 1 trường hợp.
#   REF: Các khối u đều chiếm dưới 1/3 chiều dài khí quản.Có 3 trường hợp tử vong (13,6%), do mất đoạn khí quản lớn; một sau 5 ngày, một sau 3 tuần và một sau 4 tháng.
#
# [6] Line 2910 | BLEU: 4.6 | chrF: 30.3
#   SRC: In the rest, disk hyperemia, edema in or around the disk, vessel engorgement, or a combination is present.
#   HYP: Trong số còn lại, có hiện tượng tăng tưới máu đĩa đệm, phù nề trong hoặc xung quanh đĩa đệm, tắc nghẽn mạch máu, hoặc kết hợp các biểu hiện trên.
#   REF: Có thể biểu hiện riêng lẻ cương tụ gai thị, phù trong hoặc quanh gai thị, giãn mạch ngoằn ngoèo hoặc tất cả các triệu chứng trên.
#
# [7] Line 1277 | BLEU: 4.8 | chrF: 36.1
#   SRC: The genotypes observed were in agreement with those expected under Hardy-Weinberg equilibrium.
#   HYP: Các kiểu gen quan sát được phù hợp với kiểu gen dự đoán theo định luật Hardy-Weinberg.
#   REF: Sự phân bố kiểu gen ở quần thể nghiên cứu tuân theo quy luật cân bằng Hardy - Weinberg.
#
# [8] Line 1051 | BLEU: 5.4 | chrF: 28.9
#   SRC: Most of OARs dose constraints were acceptable, though there were two cases inevitably received cochlea dose > 25Gy.
#   HYP: Hầu hết các giới hạn liều OAR đều chấp nhận được, mặc dù có 2 trường hợp không thể tránh khỏi liều ốc tai > 25Gy.
#   REF: Phần lớn liều xạ trên mô lành đều trong giới hạn cho phép, chỉ có hai trường hợp liều xạ trên ốc tai vượt qua mức giới hạn 25Gy.
#
# [9] Line 2608 | BLEU: 5.5 | chrF: 36.0
#   SRC: Morphin and Perfalgan used were lower in B vs C and there are not any complication of Bupivacain.
#   HYP: Liều morphin và Perfalgan sử dụng ở nhóm B thấp hơn nhóm C và không có biến chứng do Bupivacain.
#   REF: Lượng Perfalgan và Morphin sử dụng của nhóm can thiệp thấp hơn hẳn nhóm chứng và không ghi nhận tai biến sau bơm hay chích thuốc tê.
#
# [10] Line 1927 | BLEU: 5.5 | chrF: 26.4
#   SRC: Rate of head injury in time - when the study has done decreased.
#   HYP: Tỷ lệ chấn thương đầu trong thời gian nghiên cứu đã giảm.
#   REF: Tỷ lệ chấn thương sọ não trong thời gian khảo sát từ sau khi Nghị quyết 32 chính thức có hiệu lực và đi vào cuộc sống giảm so với cùng kỳ năm trước.

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/public_test_en2vi_sft.hyp.vi \
    --ref data/raw/public_test.vi.txt \
    --src data/raw/public_test.en.txt \
    --show_worst 10

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v1_rl/final_model \
    --direction en2vi \
    --input data/raw/public_test.en.txt \
    --output outputs/public_test_en2vi_rl.hyp.vi \
    --batch_size 16 \
    --num_beams 4 \
    --repetition_penalty 1.1
# Out:
# 2025-12-22 20:44:44.228694: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-22 20:44:44.247354: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766436284.269681  320974 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766436284.276405  320974 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766436284.293378  320974 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766436284.293419  320974 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766436284.293422  320974 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766436284.293425  320974 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-22 20:44:44.298380: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading model: Qwen/Qwen2.5-3B-Instruct
# Loading adapter: runs/en2vi_v1_rl/final_model
# Loaded tokenizer from base model
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.03it/s]
# Resizing embeddings: 151936 -> 151665
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/peft/config.py", line 317, in _get_peft_type
#     config_file = hf_hub_download(
#                   ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 154, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'runs/en2vi_v1_rl/final_model'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py", line 434, in <module>
#     main()
#   File "/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/generate.py", line 365, in main
#     model = PeftModel.from_pretrained(base, args.adapter_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/peft/peft_model.py", line 459, in from_pretrained
#     config = PEFT_TYPE_TO_CONFIG_MAPPING[PeftConfig._get_peft_type(model_id, **hf_kwargs)].from_pretrained(
#                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/peft/config.py", line 323, in _get_peft_type
#     raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
# ValueError: Can't find 'adapter_config.json' at 'runs/en2vi_v1_rl/final_model'

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/public_test_en2vi_rl.hyp.vi \
    --ref data/raw/public_test.vi.txt \
    --src data/raw/public_test.en.txt \
    --show_worst 10
# Out:
# Loading hypothesis: outputs/public_test_en2vi_rl.hyp.vi
# Traceback (most recent call last):
#   File "/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/eval_bleu.py", line 477, in <module>
#     main()
#   File "/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/eval_bleu.py", line 374, in main
#     hyp = load_file(args.hyp)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/content/BTL-NLP-2526I_INT3406_3/vlsp-mt/scripts/eval_bleu.py", line 47, in load_file
#     with open(path, encoding="utf8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/public_test_en2vi_rl.hyp.vi'

# %%
# !python scripts/generate.py \
    --model_name Qwen/Qwen2.5-3B-Instruct \
    --adapter_path runs/en2vi_v2_aug/lora_en2vi_sft \
    --direction en2vi \
    --input data/raw/public_test.en.txt \
    --output outputs/public_test_en2vi_aug.hyp.vi \
    --batch_size 16 \
    --num_beams 4 \
    --repetition_penalty 1.1

# %%
# !python scripts/eval_bleu.py \
    --hyp outputs/public_test_en2vi_aug.hyp.vi \
    --ref data/raw/public_test.vi.txt \
    --src data/raw/public_test.en.txt \
    --show_worst 10

# %% [markdown]
# # Down

# %%
import os
from huggingface_hub import HfApi, login

# Token HuggingFace
hf_token = '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'
login(hf_token)

# Cấu hình
local_folder = "vlsp-mt/runs"
repo_name = "tuan243/adapter-loRA-vlsp-mt"

# Upload
api = HfApi()

print(f"Đang tạo repo '{repo_name}'...")
api.create_repo(repo_id=repo_name, repo_type="model", exist_ok=True)

print(f"Đang đẩy model từ '{local_folder}' lên '{repo_name}'...")
api.upload_folder(
    folder_path=local_folder,
    repo_id=repo_name,
    repo_type="model"
)

print("✅ Xong! Link: https://huggingface.co/" + repo_name)

# %%
# !zip -r data12_backup.zip vlsp-mt/runs

# %%
# Copy file backup vào Google Drive
# !cp data12_backup.zip /content/drive/MyDrive/
print("Đã lưu file data_backup.zip vào Google Drive thành công!")

# %%
from google.colab import drive
import shutil

# Mount Drive
drive.mount('/content/drive')

# Zip runs
shutil.make_archive('/content/codeen2vi52', 'zip', '/content/BTL-NLP-2526I_INT3406_3/vlsp-mt')

# Copy sang Drive
shutil.copy('/content/codeen2vi52.zip', '/content/drive/MyDrive/codeen2vi52.zip')

print("Done! Vào Google Drive tải về.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Done! Vào Google Drive tải về.
